# %%
import pandas as pd
import seaborn
import matplotlib.pyplot as plt
from vega_datasets import data

# %%
carsDF = data.cars()
carsDF
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# 0         130.0           3504          12.0 1970-01-01     USA
# 1         165.0           3693          11.5 1970-01-01     USA
# 2         150.0           3436          11.0 1970-01-01     USA
# 3         150.0           3433          12.0 1970-01-01     USA
# 4         140.0           3449          10.5 1970-01-01     USA
# ..          ...            ...           ...        ...     ...
# 401        86.0           2790          15.6 1982-01-01     USA
# 402        52.0           2130          24.6 1982-01-01  Europe
# 403        84.0           2295          11.6 1982-01-01     USA
# 404        79.0           2625          18.6 1982-01-01     USA
# 405        82.0           2720          19.4 1982-01-01     USA
#
# [406 rows x 9 columns]

# %%
carsDF.columns
# Out:
# Index(['Name', 'Miles_per_Gallon', 'Cylinders', 'Displacement', 'Horsepower',
#        'Weight_in_lbs', 'Acceleration', 'Year', 'Origin'],
#       dtype='object')

# %%
cars = carsDF[['Miles_per_Gallon', 'Cylinders', 'Displacement', 'Horsepower',
       'Weight_in_lbs', 'Acceleration',]]
cars.head()
# Out:
#    Miles_per_Gallon  Cylinders  Displacement  Horsepower  Weight_in_lbs  \
# 0              18.0          8         307.0       130.0           3504
# 1              15.0          8         350.0       165.0           3693
# 2              18.0          8         318.0       150.0           3436
# 3              16.0          8         304.0       150.0           3433
# 4              17.0          8         302.0       140.0           3449
#
#    Acceleration
# 0          12.0
# 1          11.5
# 2          11.0
# 3          12.0
# 4          10.5

# %%
cars.corr()
# Out:
#                   Miles_per_Gallon  Cylinders  Displacement  Horsepower  \
# Miles_per_Gallon          1.000000  -0.775396     -0.804203   -0.778427
# Cylinders                -0.775396   1.000000      0.951787    0.844158
# Displacement             -0.804203   0.951787      1.000000    0.898326
# Horsepower               -0.778427   0.844158      0.898326    1.000000
# Weight_in_lbs            -0.831741   0.895220      0.932475    0.866586
# Acceleration              0.420289  -0.522452     -0.557984   -0.697124
#
#                   Weight_in_lbs  Acceleration
# Miles_per_Gallon      -0.831741      0.420289
# Cylinders              0.895220     -0.522452
# Displacement           0.932475     -0.557984
# Horsepower             0.866586     -0.697124
# Weight_in_lbs          1.000000     -0.430086
# Acceleration          -0.430086      1.000000

# %%
cars.corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_c441d_row0_col0, #T_c441d_row1_col1, #T_c441d_row2_col2, #T_c441d_row3_col3, #T_c441d_row4_col4, #T_c441d_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c441d_row0_col1, #T_c441d_row0_col2, #T_c441d_row0_col3, #T_c441d_row0_col4, #T_c441d_row3_col5, #T_c441d_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c441d_row0_col5 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_c441d_row1_col0, #T_c441d_row3_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c441d_row1_col2, #T_c441d_row2_col1 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_c441d_row1_col3, #T_c441d_row3_col1 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_c441d_row1_col4, #T_c441d_row2_col3, #T_c441d_row3_col2 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_c441d_row1_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c441d_row2_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c441d_row2_col4, #T_c441d_row4_col2 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_c441d_row2_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_c441d_row3_col4 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_c441d_row4_col1 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_c441d_row4_col3 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_c441d_row4_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_c441d_row5_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_c441d_row5_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c441d_row5_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c441d_row5_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c441d_row5_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c441d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Miles_per_Gallon</th>
#       <th class="col_heading level0 col1" >Cylinders</th>
#       <th class="col_heading level0 col2" >Displacement</th>
#       <th class="col_heading level0 col3" >Horsepower</th>
#       <th class="col_heading level0 col4" >Weight_in_lbs</th>
#       <th class="col_heading level0 col5" >Acceleration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c441d_level0_row0" class="row_heading level0 row0" >Miles_per_Gallon</th>
#       <td id="T_c441d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c441d_row0_col1" class="data row0 col1" >-0.775396</td>
#       <td id="T_c441d_row0_col2" class="data row0 col2" >-0.804203</td>
#       <td id="T_c441d_row0_col3" class="data row0 col3" >-0.778427</td>
#       <td id="T_c441d_row0_col4" class="data row0 col4" >-0.831741</td>
#       <td id="T_c441d_row0_col5" class="data row0 col5" >0.420289</td>
#     </tr>
#     <tr>
#       <th id="T_c441d_level0_row1" class="row_heading level0 row1" >Cylinders</th>
#       <td id="T_c441d_row1_col0" class="data row1 col0" >-0.775396</td>
#       <td id="T_c441d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c441d_row1_col2" class="data row1 col2" >0.951787</td>
#       <td id="T_c441d_row1_col3" class="data row1 col3" >0.844158</td>
#       <td id="T_c441d_row1_col4" class="data row1 col4" >0.895220</td>
#       <td id="T_c441d_row1_col5" class="data row1 col5" >-0.522452</td>
#     </tr>
#     <tr>
#       <th id="T_c441d_level0_row2" class="row_heading level0 row2" >Displacement</th>
#       <td id="T_c441d_row2_col0" class="data row2 col0" >-0.804203</td>
#       <td id="T_c441d_row2_col1" class="data row2 col1" >0.951787</td>
#       <td id="T_c441d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c441d_row2_col3" class="data row2 col3" >0.898326</td>
#       <td id="T_c441d_row2_col4" class="data row2 col4" >0.932475</td>
#       <td id="T_c441d_row2_col5" class="data row2 col5" >-0.557984</td>
#     </tr>
#     <tr>
#       <th id="T_c441d_level0_row3" class="row_heading level0 row3" >Horsepower</th>
#       <td id="T_c441d_row3_col0" class="data row3 col0" >-0.778427</td>
#       <td id="T_c441d_row3_col1" class="data row3 col1" >0.844158</td>
#       <td id="T_c441d_row3_col2" class="data row3 col2" >0.898326</td>
#       <td id="T_c441d_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c441d_row3_col4" class="data row3 col4" >0.866586</td>
#       <td id="T_c441d_row3_col5" class="data row3 col5" >-0.697124</td>
#     </tr>
#     <tr>
#       <th id="T_c441d_level0_row4" class="row_heading level0 row4" >Weight_in_lbs</th>
#       <td id="T_c441d_row4_col0" class="data row4 col0" >-0.831741</td>
#       <td id="T_c441d_row4_col1" class="data row4 col1" >0.895220</td>
#       <td id="T_c441d_row4_col2" class="data row4 col2" >0.932475</td>
#       <td id="T_c441d_row4_col3" class="data row4 col3" >0.866586</td>
#       <td id="T_c441d_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_c441d_row4_col5" class="data row4 col5" >-0.430086</td>
#     </tr>
#     <tr>
#       <th id="T_c441d_level0_row5" class="row_heading level0 row5" >Acceleration</th>
#       <td id="T_c441d_row5_col0" class="data row5 col0" >0.420289</td>
#       <td id="T_c441d_row5_col1" class="data row5 col1" >-0.522452</td>
#       <td id="T_c441d_row5_col2" class="data row5 col2" >-0.557984</td>
#       <td id="T_c441d_row5_col3" class="data row5 col3" >-0.697124</td>
#       <td id="T_c441d_row5_col4" class="data row5 col4" >-0.430086</td>
#       <td id="T_c441d_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(10,10))
seaborn.heatmap(cars.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
from scipy import stats

def  corrfunc(x, y, **kws):
    r, _ = stats.pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r), xy=(0.2, 1), xycoords = ax.transAxes)

cars_pairplot = cars.dropna()

pair_plot = seaborn.pairplot(cars_pairplot, height = 1.5)
pair_plot.map_lower(corrfunc)
pair_plot.map_upper(corrfunc)
